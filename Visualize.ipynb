# %% [markdown]
# # Visualizing Convolutional Layer Activations on Poisoned and Clean Data

# %% [markdown]
# ## Package Imports

# %%
import pickle
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# ## Loading Convolutional Layer Activations

# %%
# Loading instruction data obtained from Ghidra block analysis.
activation_rate_clean_test = {}
activation_rate_poisoned_train = {}
difference_activation_block1_conv1 = {}
difference_activation_block2_conv1 = {}
with open('activation_rate_clean_test', 'rb') as f:
    activation_rate_clean_test = pickle.load(f)

with open('activation_rate_poisoned_train', 'rb') as f:
    activation_rate_poisoned_train = pickle.load(f)
    
with open('difference_activation_block1_conv1', 'rb') as f:
    difference_activation_block1_conv1 = pickle.load(f)
    
with open('difference_activation_block2_conv1', 'rb') as f:
    difference_activation_block2_conv1 = pickle.load(f)

# %%
sb.set()
# sb.heatmap(activation_rate_clean_test)
# sb.heatmap(activation_rate_poisoned_train)
# sb.heatmap(difference_activation_block1_conv1)
fig, ax = plt.subplots(figsize=(20,15))
# sb.heatmap(difference_activation_block2_conv1)
# sb.heatmap(activation_rate_clean_test)
# sb.heatmap(activation_rate_poisoned_train)
sb.heatmap(difference_activation_block1_conv1)
